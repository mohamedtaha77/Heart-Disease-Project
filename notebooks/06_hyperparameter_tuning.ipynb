# %% [markdown]
# ## **2.6 Hyperparameter Tuning**

# %% [markdown]
# **Import Required Libraries**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from scipy.stats import randint

# %% [markdown]
# **Define Hyperparameter Grid for GridSearchCV**

# %%
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

# %% [markdown]
# **Run GridSearchCV on Random Forest**

# %%
rf = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(estimator=rf,
                           param_grid=param_grid,
                           cv=5,
                           scoring='f1_weighted',
                           n_jobs=-1,
                           verbose=1)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150]},
#              scoring='f1_weighted', verbose=1)

# %% [markdown]
# **Show Best Parameters and Score from Grid Search**

# %%
print("Best Parameters from GridSearchCV:", grid_search.best_params_)
print("Best F1 Score (CV average):", grid_search.best_score_)
# Out:
# Best Parameters from GridSearchCV: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 100}
# Best F1 Score (CV average): 0.5098143856007116

# %% [markdown]
# **Grid Search results**

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.288605      0.062411         0.031932        0.010855
# 1        0.972533      0.564286         0.064447        0.046782
# 2        0.450808      0.052297         0.026283        0.000767
# 3        0.137667      0.001472         0.013364        0.001161
# 4        0.276612      0.016215         0.019573        0.000682
# ..            ...           ...              ...             ...
# 67       0.404968      0.059103         0.034123        0.011511
# 68       0.681002      0.126561         0.039726        0.012048
# 69       0.211448      0.047166         0.020276        0.007541
# 70       0.420326      0.072688         0.023525        0.008749
# 71       0.588624      0.139971         0.032387        0.013847
#
#    param_criterion param_max_depth  param_min_samples_split  \
# 0             gini            None                        2
# 1             gini            None                        2
# 2             gini            None                        2
# 3             gini            None                        5
# 4             gini            None                        5
# ..             ...             ...                      ...
# 67         entropy              20                        5
# 68         entropy              20                        5
# 69         entropy              20                       10
# 70         entropy              20                       10
# 71         entropy              20                       10
#
#     param_n_estimators                                             params  \
# 0                   50  {'criterion': 'gini', 'max_depth': None, 'min_...
# 1                  100  {'criterion': 'gini', 'max_depth': None, 'min_...
# 2                  150  {'criterion': 'gini', 'max_depth': None, 'min_...
# 3                   50  {'criterion': 'gini', 'max_depth': None, 'min_...
# 4                  100  {'criterion': 'gini', 'max_depth': None, 'min_...
# ..                 ...                                                ...
# 67                 100  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 68                 150  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 69                  50  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 70                 100  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 71                 150  {'criterion': 'entropy', 'max_depth': 20, 'min...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.451868           0.505019           0.461738
# 1            0.431034           0.501374           0.501605
# 2            0.499708           0.495144           0.499671
# 3            0.521289           0.536125           0.473888
# 4            0.533929           0.520833           0.501058
# ..                ...                ...                ...
# 67           0.491663           0.525555           0.462876
# 68           0.448994           0.479911           0.471220
# 69           0.477098           0.468750           0.439594
# 70           0.477098           0.479911           0.501605
# 71           0.482328           0.482772           0.457447
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.482941           0.567400         0.493793        0.041102
# 1            0.483862           0.535386         0.490652        0.034166
# 2            0.482412           0.494192         0.494225        0.006326
# 3            0.497139           0.491742         0.504036        0.022068
# 4            0.487054           0.479685         0.504512        0.020322
# ..                ...                ...              ...             ...
# 67           0.520954           0.472399         0.494689        0.025142
# 68           0.520954           0.437911         0.471798        0.028813
# 69           0.426648           0.463443         0.455107        0.018920
# 70           0.479737           0.414700         0.470610        0.029321
# 71           0.463815           0.408282         0.458929        0.027229
#
#     rank_test_score
# 0                19
# 1                23
# 2                17
# 3                 7
# 4                 5
# ..              ...
# 67               15
# 68               46
# 69               64
# 70               48
# 71               60
#
# [72 rows x 17 columns]

# %% [markdown]
# **RandomizedSearchCV for Faster Tuning**

# %%
param_dist = {
    'n_estimators': randint(50, 200),
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': randint(2, 11),
    'criterion': ['gini', 'entropy']
}

random_search = RandomizedSearchCV(estimator=rf,
                                   param_distributions=param_dist,
                                   n_iter=20,
                                   cv=5,
                                   scoring='f1_weighted',
                                   random_state=42,
                                   n_jobs=-1,
                                   verbose=1)

random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 5, 10, 20],
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7896de5298d0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7896de608b90>},
#                    random_state=42, scoring='f1_weighted', verbose=1)

# %% [markdown]
# **Best Parameters from Randomized Search**

# %%
print("Best Parameters from RandomizedSearchCV:", random_search.best_params_)
print("Best F1 Score (CV average):", random_search.best_score_)
# Out:
# Best Parameters from RandomizedSearchCV: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 3, 'n_estimators': 181}
# Best F1 Score (CV average): 0.4973803640523965

# %% [markdown]
# **Randomized Search results**

# %%
pd.DataFrame(random_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.191936      0.004196         0.014868        0.000272
# 1        0.341699      0.010436         0.022763        0.001786
# 2        1.655652      0.846439         0.120779        0.058242
# 3        1.777767      0.155000         0.097280        0.021485
# 4        0.635671      0.150242         0.045560        0.017774
# 5        0.441633      0.031745         0.028966        0.009627
# 6        0.348484      0.055135         0.023661        0.010935
# 7        0.900516      0.234499         0.058452        0.022668
# 8        1.194548      0.111492         0.066625        0.020463
# 9        0.347821      0.067783         0.032049        0.009009
# 10       0.766757      0.077369         0.042859        0.017584
# 11       0.278049      0.045308         0.025206        0.006451
# 12       0.540336      0.116467         0.032051        0.009576
# 13       0.159786      0.009781         0.013999        0.000820
# 14       0.286255      0.018767         0.019233        0.000464
# 15       0.526757      0.015640         0.030074        0.000693
# 16       0.283354      0.005828         0.023567        0.008220
# 17       0.269914      0.033972         0.019827        0.001124
# 18       0.180512      0.015375         0.014420        0.000390
# 19       0.303495      0.056925         0.021838        0.009749
#
#    param_criterion param_max_depth  param_min_samples_split  \
# 0             gini              20                        9
# 1             gini               5                        4
# 2             gini              20                        6
# 3          entropy              20                        4
# 4             gini               5                        9
# 5          entropy              20                        6
# 6          entropy            None                       10
# 7             gini              10                        4
# 8             gini              20                       10
# 9             gini              10                        8
# 10            gini              10                        3
# 11            gini              20                        3
# 12         entropy            None                        3
# 13         entropy              10                        8
# 14            gini              10                        2
# 15         entropy              20                        3
# 16         entropy               5                        5
# 17            gini              10                        3
# 18         entropy               5                        5
# 19            gini              20                        9
#
#     param_n_estimators                                             params  \
# 0                   70  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
# 1                  124  {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 2                  149  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
# 3                  199  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 4                   87  {'criterion': 'gini', 'max_depth': 5, 'min_sam...
# 5                  107  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 6                   98  {'criterion': 'entropy', 'max_depth': None, 'm...
# 7                  157  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 8                  180  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
# 9                   70  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 10                 181  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 11                  58  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
# 12                 133  {'criterion': 'entropy', 'max_depth': None, 'm...
# 13                  57  {'criterion': 'entropy', 'max_depth': 10, 'min...
# 14                  99  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 15                 183  {'criterion': 'entropy', 'max_depth': 20, 'min...
# 16                 103  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 17                  93  {'criterion': 'gini', 'max_depth': 10, 'min_sa...
# 18                  63  {'criterion': 'entropy', 'max_depth': 5, 'min_...
# 19                  89  {'criterion': 'gini', 'max_depth': 20, 'min_sa...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.485502           0.511161           0.473243
# 1            0.490205           0.496909           0.471036
# 2            0.482143           0.509558           0.454610
# 3            0.479762           0.447058           0.508473
# 4            0.453259           0.523661           0.411805
# 5            0.471930           0.445685           0.489562
# 6            0.477098           0.450555           0.501605
# 7            0.534649           0.447058           0.488339
# 8            0.482328           0.461324           0.459588
# 9            0.527530           0.491453           0.456770
# 10           0.551339           0.510904           0.524859
# 11           0.474311           0.511891           0.509659
# 12           0.515205           0.523049           0.455004
# 13           0.441384           0.511161           0.451233
# 14           0.493304           0.482772           0.469575
# 15           0.466851           0.473587           0.485794
# 16           0.490205           0.461324           0.436286
# 17           0.482143           0.526466           0.527137
# 18           0.492586           0.496429           0.437898
# 19           0.459241           0.523661           0.492270
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.482270           0.491078         0.488651        0.012654
# 1            0.459811           0.438972         0.471387        0.020930
# 2            0.453167           0.440232         0.467942        0.024890
# 3            0.520954           0.414700         0.474190        0.039162
# 4            0.482270           0.438972         0.461993        0.038312
# 5            0.517847           0.444160         0.473837        0.027789
# 6            0.479737           0.414700         0.464739        0.029806
# 7            0.503224           0.440678         0.482790        0.035179
# 8            0.453167           0.435598         0.458401        0.015032
# 9            0.463728           0.470887         0.482074        0.025519
# 10           0.455531           0.444269         0.497380        0.041041
# 11           0.515224           0.430971         0.488411        0.032311
# 12           0.485635           0.458681         0.487515        0.028005
# 13           0.521760           0.445390         0.474186        0.034821
# 14           0.465777           0.534290         0.489144        0.024597
# 15           0.485635           0.514894         0.485352        0.016454
# 16           0.470316           0.438972         0.459421        0.020116
# 17           0.512184           0.437405         0.497067        0.033998
# 18           0.489156           0.532297         0.489673        0.030172
# 19           0.482270           0.438972         0.479283        0.028891
#
#     rank_test_score
# 0                 5
# 1                15
# 2                16
# 3                12
# 4                18
# 5                14
# 6                17
# 7                 9
# 8                20
# 9                10
# 10                1
# 11                6
# 12                7
# 13               13
# 14                4
# 15                8
# 16               19
# 17                2
# 18                3
# 19               11

# %% [markdown]
# **Save best models after tuning**

# %%
best_rf_model = grid_search.best_estimator_

# Evaluate on test set
y_pred_best = best_rf_model.predict(X_test)
from sklearn.metrics import classification_report
print("Classification Report for Best RF Model:")
print(classification_report(y_test, y_pred_best))
# Out:
# Classification Report for Best RF Model:
#               precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84        36
#            1       0.00      0.00      0.00         9
#            2       0.33      0.20      0.25         5
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.58        60
#    macro avg       0.22      0.23      0.22        60
# weighted avg       0.48      0.58      0.52        60

# %%
best_rf_model = random_search.best_estimator_

# Evaluate on test set
y_pred_best = best_rf_model.predict(X_test)
from sklearn.metrics import classification_report
print("Classification Report for Best RF Model:")
print(classification_report(y_test, y_pred_best))
# Out:
# Classification Report for Best RF Model:
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84        36
#            1       0.00      0.00      0.00         9
#            2       0.33      0.20      0.25         5
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.22      0.23      0.22        60
# weighted avg       0.47      0.60      0.53        60

# %% [markdown]
# ### ✅ Deliverables:
#
# - Best hyperparameters from `GridSearchCV` and/or `RandomizedSearchCV`
# - Best cross-validated F1-score for Random Forest
# - Grid/Randomized Search results for reporting
# - Optimized Random Forest model ready for final evaluation or deployment
#
# **Next Step:** 2.7 Model Export & Deployment

# %% [markdown]
# ## **2.7 Model Export & Deployment**

# %% [markdown]
# **Import joblib for exporting the model**

# %%
import joblib

# %% [markdown]
# **Define column types**

# %%
# These are raw input columns
columns = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
           "thalach", "exang", "oldpeak", "slope", "ca", "thal"]

categorical_cols = ['cp', 'thal', 'slope']
numerical_cols = [col for col in columns if col not in categorical_cols]

# %% [markdown]
# **Build preprocessor + pipeline**

# %%
# Preprocessing
preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numerical_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
])

# Full pipeline
pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('classifier', RandomForestClassifier(random_state=42))
])

# %% [markdown]
# **Fit the pipeline on the original (raw) dataset**

# %%
# Reloading original dataset (before one-hot encoding)
columns = [
    "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
    "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"
]

df_raw = pd.read_csv("heart_disease.csv", header=None, names=columns)
df_raw.replace("?", pd.NA, inplace=True)
df_raw = df_raw.apply(pd.to_numeric, errors="coerce").dropna().reset_index(drop=True)

# Prepare input and target
X_raw = df_raw[columns[:-1]]   # the 13 raw features
y_raw = df_raw["target"]

# %%
pipeline.fit(X_raw, y_raw)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'sex', 'trestbps',
#                                                    'chol', 'fbs', 'restecg',
#                                                    'thalach', 'exang',
#                                                    'oldpeak', 'ca']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['cp', 'thal', 'slope'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
joblib.dump(pipeline, 'heart_disease_pipeline.pkl')
print("✅ Pipeline saved as 'heart_disease_pipeline.pkl'")
# Out:
# ✅ Pipeline saved as 'heart_disease_pipeline.pkl'

# %% [markdown]
# ### ✅ Deliverables:
#
# - `best_random_forest_model.pkl`: optimized model
# - `scaler.pkl`: saved StandardScaler
# - `heart_disease_pipeline.pkl`: full preprocessing + model pipeline
#
# **Next Step:** 2.8 Streamlit Web UI Development [Bonus]

# %% [markdown]
# **File Download Cell**

# %%
from google.colab import files
import joblib

# Save the pipeline
joblib.dump(pipeline, 'heart_disease_pipeline.pkl')

# Save the dataset
df_raw.to_csv('heart_disease.csv', index=False)

# Create a requirements file
# !pip freeze > requirements.txt

# Download files
files.download('heart_disease_pipeline.pkl')
files.download('heart_disease.csv')
files.download('requirements.txt')
